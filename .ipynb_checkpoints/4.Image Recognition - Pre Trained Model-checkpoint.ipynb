# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.4.1'

# %% [markdown]
# ### Image Classification
#
# We are going to classify different images (downloading from the internet) using tensorflow's pre-trained model (**ResNet50**)

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import resnet50

# %%
# Initialize the model

model = resnet50.ResNet50()

# %%
# extracting jpg images from the directory
# %cd "image recoginition"
# %ls *.jpg
# Out:
# C:\Waqas Documents\Waqas\W.A\Programming\Data Sciecnce\With Python\Aman Kharwal\Data Science Projects -Advanced 3\image recoginition
#  Volume in drive C is Windows
#  Volume Serial Number is EEBF-2F4D
#
#  Directory of C:\Waqas Documents\Waqas\W.A\Programming\Data Sciecnce\With Python\Aman Kharwal\Data Science Projects -Advanced 3\image recoginition
#
# 01/27/2021  09:37 AM             8,149 car.jpg
# 01/27/2021  09:38 AM             8,076 cat.jpg
# 01/27/2021  09:40 AM             5,864 images.jpg
# 01/27/2021  09:39 AM             7,938 shirt.jpg
#                4 File(s)         30,027 bytes
#                0 Dir(s)  141,247,021,056 bytes free

# %%
images = ["image recoginition/car.jpg","image recoginition/cat.jpg",
          "image recoginition/images.jpg","image recoginition/shirt.jpg"]

# %%
# %cd ..
# Out:
# C:\Waqas Documents\Waqas\W.A\Programming\Data Sciecnce\With Python\Aman Kharwal\Data Science Projects -Advanced 3

# %%
# display image
car = image.load_img("image recoginition/car.jpg", target_size= (224,224))
car
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x282864168C8>

# %%
# convert image to array

car_array = image.img_to_array(car)
print(car_array.shape)
print(car_array[:2])
# Out:
# (224, 224, 3)
# [[[61. 64. 57.]
#   [62. 65. 58.]
#   [65. 68. 61.]
#   ...
#   [55. 51. 48.]
#   [54. 54. 46.]
#   [59. 59. 51.]]
#
#  [[61. 64. 57.]
#   [62. 65. 58.]
#   [65. 68. 61.]
#   ...
#   [33. 29. 28.]
#   [63. 62. 57.]
#   [68. 67. 62.]]]

# %%
# Reshape image into 4 dimension (1,width, height, colors)

car_reshape = car_array.reshape((1,224,224,3))
print(car_reshape.shape)
print(car_reshape[0])
# Out:
# (1, 224, 224, 3)
# [[[61. 64. 57.]
#   [62. 65. 58.]
#   [65. 68. 61.]
#   ...
#   [55. 51. 48.]
#   [54. 54. 46.]
#   [59. 59. 51.]]
#
#  [[61. 64. 57.]
#   [62. 65. 58.]
#   [65. 68. 61.]
#   ...
#   [33. 29. 28.]
#   [63. 62. 57.]
#   [68. 67. 62.]]
#
#  [[60. 63. 56.]
#   [61. 64. 57.]
#   [64. 67. 60.]
#   ...
#   [52. 48. 47.]
#   [66. 64. 65.]
#   [69. 67. 68.]]
#
#  ...
#
#  [[ 7.  7.  7.]
#   [ 7.  7.  7.]
#   [ 7.  7.  7.]
#   ...
#   [12. 10. 11.]
#   [11. 11. 11.]
#   [11. 11. 11.]]
#
#  [[ 7.  7.  7.]
#   [ 7.  7.  7.]
#   [ 7.  7.  7.]
#   ...
#   [10.  8.  9.]
#   [ 9.  9.  9.]
#   [ 9.  9.  9.]]
#
#  [[ 7.  7.  7.]
#   [ 7.  7.  7.]
#   [ 7.  7.  7.]
#   ...
#   [ 9.  7.  8.]
#   [ 7.  7.  7.]
#   [ 7.  7.  7.]]]

# %%
# preprocess the image for prediction. This step is optional

processed_img = resnet50.preprocess_input(car_reshape)
print(processed_img.shape)
processed_img
# Out:
# (1, 224, 224, 3)
# array([[[[ -46.939003,  -52.779   ,  -62.68    ],
#          [ -45.939003,  -51.779   ,  -61.68    ],
#          [ -42.939003,  -48.779   ,  -58.68    ],
#          ...,
#          [ -55.939003,  -65.779   ,  -68.68    ],
#          [ -57.939003,  -62.779   ,  -69.68    ],
#          [ -52.939003,  -57.779   ,  -64.68    ]],
#
#         [[ -46.939003,  -52.779   ,  -62.68    ],
#          [ -45.939003,  -51.779   ,  -61.68    ],
#          [ -42.939003,  -48.779   ,  -58.68    ],
#          ...,
#          [ -75.939   ,  -87.779   ,  -90.68    ],
#          [ -46.939003,  -54.779   ,  -60.68    ],
#          [ -41.939003,  -49.779   ,  -55.68    ]],
#
#         [[ -47.939003,  -53.779   ,  -63.68    ],
#          [ -46.939003,  -52.779   ,  -62.68    ],
#          [ -43.939003,  -49.779   ,  -59.68    ],
#          ...,
#          [ -56.939003,  -68.779   ,  -71.68    ],
#          [ -38.939003,  -52.779   ,  -57.68    ],
#          [ -35.939003,  -49.779   ,  -54.68    ]],
#
#         ...,
#
#         [[ -96.939   , -109.779   , -116.68    ],
#          [ -96.939   , -109.779   , -116.68    ],
#          [ -96.939   , -109.779   , -116.68    ],
#          ...,
#          [ -92.939   , -106.779   , -111.68    ],
#          [ -92.939   , -105.779   , -112.68    ],
#          [ -92.939   , -105.779   , -112.68    ]],
#
#         [[ -96.939   , -109.779   , -116.68    ],
#          [ -96.939   , -109.779   , -116.68    ],
#          [ -96.939   , -109.779   , -116.68    ],
#          ...,
#          [ -94.939   , -108.779   , -113.68    ],
#          [ -94.939   , -107.779   , -114.68    ],
#          [ -94.939   , -107.779   , -114.68    ]],
#
#         [[ -96.939   , -109.779   , -116.68    ],
#          [ -96.939   , -109.779   , -116.68    ],
#          [ -96.939   , -109.779   , -116.68    ],
#          ...,
#          [ -95.939   , -109.779   , -114.68    ],
#          [ -96.939   , -109.779   , -116.68    ],
#          [ -96.939   , -109.779   , -116.68    ]]]], dtype=float32)

# %%
prediction = model.predict(processed_img)
prediction.shape
# Out:
# (1, 1000)

# %%
# Decode the prediction

classification = resnet50.decode_predictions(prediction)
classification
# Out:
# [[('n03770679', 'minivan', 0.32660726),
#   ('n02974003', 'car_wheel', 0.100174695),
#   ('n09193705', 'alp', 0.09935893),
#   ('n03930630', 'pickup', 0.054291993),
#   ('n04461696', 'tow_truck', 0.04834894)]]

# %%
classification[0][0][1]
# Out:
# 'minivan'

# %%
# classifying all the images using above procedure

for img in images:
    load_img = image.load_img(img, target_size= (224,224))
    img_array = image.img_to_array(load_img)
    reshape_array = img_array.reshape((1,224,224,3))
    processed = resnet50.preprocess_input(reshape_array)
    prediction = model.predict(processed)
    classification = resnet50.decode_predictions(prediction)
    print("This is the "+ classification[0][0][1])
# Out:
# This is the minivan
# This is the lynx
# This is the bulletproof_vest
# This is the Loafer

# %%
# Removing processed_input method

for img in images:
    load_img = image.load_img(img, target_size= (224,224))
    img_array = image.img_to_array(load_img)
    reshape_array = img_array.reshape((1,224,224,3))
    # processed = resnet50.preprocess_input(reshape_array)
    prediction = model.predict(reshape_array)
    classification = resnet50.decode_predictions(prediction)
    print("This is the "+ classification[0][0][1])
# Out:
# This is the convertible
# This is the lynx
# This is the wool
# This is the Loafer
